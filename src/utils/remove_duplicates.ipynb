# %% [markdown]
# Referenced: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset/discussion/482896

# %%
import hashlib
import os
import pandas as pd

# %%
def compute_hash(file):
    hasher = hashlib.md5()
    with open(file, 'rb') as f:
        buf = f.read()
        hasher.update(buf)
    return hasher.hexdigest()

LABELS = ['glioma', 'meningioma', 'notumor', 'pituitary']
def list_files(hash_dict):
    for data_type in ['Training', 'Testing']:
        for label in LABELS:
            folder_path = os.path.join(data_type, label)
            for root, dirs, files in os.walk(folder_path):
                for file in files:
                    if file.endswith(".jpg"):
                        file_path = os.path.join(root, file)
                        file_hash = compute_hash(file_path)
                        if file_hash in hash_dict:
                            hash_dict[file_hash].append(file_path)
                        else:
                            hash_dict[file_hash] = [file_path]

hash_dict = {}
list_files(hash_dict)

# %%
len(hash_dict)
# Out:
# 6726

# %%
def remove_duplicates(hash_dict):
    duplicate_count = 0
    for hash_value, file_paths in hash_dict.items():
        if len(file_paths) > 1:
            for file_path in file_paths[1:]:
                print(f"Removing duplicate (hash : {hash_value}) : {file_path}")
                os.remove(file_path)
                duplicate_count += 1
    print(f"Number of duplicates : {duplicate_count}")

# %%
remove_duplicates(hash_dict)
# Out:
# Removing duplicate (hash : b0481c04cf82055b53bed325556f744e) : Testing\meningioma\Te-me_0135.jpg
# Removing duplicate (hash : ab525628d00898aa6b1088d9c1d5a785) : Training\meningioma\Tr-me_0281.jpg
# Removing duplicate (hash : af3a4cf5d54bd454b733bfe3d2177b4a) : Training\meningioma\Tr-me_0211.jpg
# Removing duplicate (hash : af3a4cf5d54bd454b733bfe3d2177b4a) : Training\meningioma\Tr-me_0366.jpg
# Removing duplicate (hash : a501e6ea3748d3aebea8e8735268ec5b) : Training\meningioma\Tr-me_0238.jpg
# Removing duplicate (hash : 333ca271271562e025951545e76a8b0b) : Training\meningioma\Tr-me_0251.jpg
# Removing duplicate (hash : 3cb1d6594ea1a7391608e9bc8245529c) : Testing\meningioma\Te-me_0143.jpg
# Removing duplicate (hash : 832c3e0243e8fafe4313d899e233285d) : Training\meningioma\Tr-me_0617.jpg
# Removing duplicate (hash : 7be661c7ec1d3c648894b51bb7ffdf3e) : Training\notumor\Tr-no_1059.jpg
# Removing duplicate (hash : 713df8b9d91cb6721c6e2478df82fc02) : Training\notumor\Tr-no_0994.jpg
# Removing duplicate (hash : 5474914546a6267f70286341ef9c9052) : Training\notumor\Tr-no_0029.jpg
# Removing duplicate (hash : 961071052eb301a3e0cd452df5cfa975) : Training\notumor\Tr-no_1047.jpg
# Removing duplicate (hash : 4c8a57ca4fda6790732ae397b23acfa3) : Training\notumor\Tr-no_1052.jpg
# Removing duplicate (hash : f4b4f54022e5d07d1cfecf6868492299) : Training\notumor\Tr-no_0012.jpg
# Removing duplicate (hash : f4b4f54022e5d07d1cfecf6868492299) : Training\notumor\Tr-no_0024.jpg
# Removing duplicate (hash : e0e9fee7b1fe0b3a4fc4af3189e2dc1f) : Training\notumor\Tr-no_0014.jpg
# Removing duplicate (hash : e0e9fee7b1fe0b3a4fc4af3189e2dc1f) : Training\notumor\Tr-no_1055.jpg
# Removing duplicate (hash : 7ab84ada9eeadbc4f93ae1afcf38628b) : Training\notumor\Tr-no_1056.jpg
# Removing duplicate (hash : bc7e75fa5d8cff54b445b79275272d54) : Training\notumor\Tr-no_1057.jpg
# Removing duplicate (hash : e8987ab719f704faf79a88816c763226) : Training\notumor\Tr-no_1058.jpg
# Removing duplicate (hash : 2c7025438fab31a227acfa917e126d33) : Training\notumor\Tr-no_1063.jpg
# Removing duplicate (hash : 7f4d91f6e5c91dc0501e9d9562042f58) : Training\notumor\Tr-no_1064.jpg
# Removing duplicate (hash : 9a96042ca9379abbdb7be132cb833221) : Training\notumor\Tr-no_1066.jpg
# Removing duplicate (hash : 3c6fa0ae2ede310bc6dc2dd7a6fbbaa3) : Training\notumor\Tr-no_1067.jpg
# Removing duplicate (hash : 6b3c032ec42efd24bdeb87534f6ce0bd) : Training\notumor\Tr-no_1068.jpg
# Removing duplicate (hash : ce0edd8064f376cf8360d63c4d9ebdd8) : Training\notumor\Tr-no_1069.jpg
# Removing duplicate (hash : 8d5cb4ac464ba805ec639f4c38da6191) : Training\notumor\Tr-no_1070.jpg
# Removing duplicate (hash : 06c3e21e888012e7845da47b26b742e8) : Training\notumor\Tr-no_1072.jpg
# Removing duplicate (hash : d3692b5c51d63ded1b913019a2027789) : Training\notumor\Tr-no_1073.jpg
# Removing duplicate (hash : e8cf02f5f074423443117f693bef9a33) : Training\notumor\Tr-no_1077.jpg
# Removing duplicate (hash : 75378ac81f02855ccf2b17a8492f3941) : Training\notumor\Tr-no_1078.jpg
# Removing duplicate (hash : fdea69d8f1eaf6ad0933a4e4ba3cc4f6) : Training\notumor\Tr-no_1079.jpg
# Removing duplicate (hash : aa86a91e84f337895ac6c95378e5cc54) : Training\notumor\Tr-no_1080.jpg
# Removing duplicate (hash : 547162f38043fe5cf612896adbaa193e) : Training\notumor\Tr-no_1081.jpg
# Removing duplicate (hash : 9fc3b080c7fe9c1d3927b877b975b5f1) : Training\notumor\Tr-no_1082.jpg
# Removing duplicate (hash : 93d4bba38c027c84aee1f2a001e685a4) : Training\notumor\Tr-no_0338.jpg
# Removing duplicate (hash : 93d4bba38c027c84aee1f2a001e685a4) : Training\notumor\Tr-no_1084.jpg
# Removing duplicate (hash : 93d4bba38c027c84aee1f2a001e685a4) : Testing\notumor\Te-no_0022.jpg
# Removing duplicate (hash : 93d4bba38c027c84aee1f2a001e685a4) : Testing\notumor\Te-no_0075.jpg
# Removing duplicate (hash : 822450ec762df8937bb87461d0ad34fa) : Testing\notumor\Te-no_0033.jpg
# Removing duplicate (hash : b9504d1f84629a48b2de81a52aa0468a) : Training\notumor\Tr-no_0077.jpg
# Removing duplicate (hash : 6142acdc1f1b32e31ea0f73324b5f356) : Training\notumor\Tr-no_0078.jpg
# Removing duplicate (hash : 208670d4d74e93c59795a71a6e8edaf1) : Training\notumor\Tr-no_0079.jpg
# Removing duplicate (hash : ddc6fd51d45cb3a708c10fb921485ce9) : Training\notumor\Tr-no_0081.jpg
# Removing duplicate (hash : db91bc187f17cccca2c4611a600dd5e7) : Testing\notumor\Te-no_0034.jpg
# Removing duplicate (hash : 570a2e1a8b1c1513f3eeaefce22b77d5) : Training\notumor\Tr-no_0345.jpg
# Removing duplicate (hash : 570a2e1a8b1c1513f3eeaefce22b77d5) : Training\notumor\Tr-no_0985.jpg
# Removing duplicate (hash : 570a2e1a8b1c1513f3eeaefce22b77d5) : Testing\notumor\Te-no_0035.jpg
# Removing duplicate (hash : 570a2e1a8b1c1513f3eeaefce22b77d5) : Testing\notumor\Te-no_0081.jpg
# Removing duplicate (hash : 33545775c68d06694c0cd52a399584a7) : Training\notumor\Tr-no_0181.jpg
# Removing duplicate (hash : 300e1604b650132eb5b2b28c9888fb5b) : Training\notumor\Tr-no_0968.jpg
# Removing duplicate (hash : 300e1604b650132eb5b2b28c9888fb5b) : Testing\notumor\Te-no_0036.jpg
# Removing duplicate (hash : 25faac854458973ea07975165f80c035) : Training\notumor\Tr-no_0159.jpg
# Removing duplicate (hash : 25faac854458973ea07975165f80c035) : Training\notumor\Tr-no_1114.jpg
# Removing duplicate (hash : c2c5423dd557bd3557a8bd8d4f359acf) : Training\notumor\Tr-no_1092.jpg
# Removing duplicate (hash : 04ad12436c5b59dac34ff27b48e8dd9a) : Training\notumor\Tr-no_1093.jpg
# Removing duplicate (hash : 04ad12436c5b59dac34ff27b48e8dd9a) : Testing\notumor\Te-no_0037.jpg
# Removing duplicate (hash : bbe4e3817fcf574daf45adf8a2915106) : Training\notumor\Tr-no_0130.jpg
# Removing duplicate (hash : bbe4e3817fcf574daf45adf8a2915106) : Training\notumor\Tr-no_0132.jpg
# Removing duplicate (hash : 24e83deaaae9ab0f15565690e474f5fc) : Training\notumor\Tr-no_0131.jpg
# Removing duplicate (hash : 24e83deaaae9ab0f15565690e474f5fc) : Training\notumor\Tr-no_0366.jpg
# Removing duplicate (hash : 24e83deaaae9ab0f15565690e474f5fc) : Training\notumor\Tr-no_0369.jpg
# Removing duplicate (hash : 24e83deaaae9ab0f15565690e474f5fc) : Training\notumor\Tr-no_1095.jpg
# Removing duplicate (hash : 1f23dacaac228811e45af94981be031c) : Training\notumor\Tr-no_0123.jpg
# Removing duplicate (hash : 1f23dacaac228811e45af94981be031c) : Training\notumor\Tr-no_0136.jpg
# Removing duplicate (hash : d966ed9f01d9fac152e7a4bed63ac281) : Training\notumor\Tr-no_0122.jpg
# Removing duplicate (hash : 1829d716613d6d3022da2f82368071ae) : Training\notumor\Tr-no_0125.jpg
# Removing duplicate (hash : 1829d716613d6d3022da2f82368071ae) : Training\notumor\Tr-no_0365.jpg
# Removing duplicate (hash : 1829d716613d6d3022da2f82368071ae) : Training\notumor\Tr-no_0368.jpg
# Removing duplicate (hash : 833431d3c05dd4975af7ca2b362dfc84) : Training\notumor\Tr-no_1094.jpg
# Removing duplicate (hash : 833431d3c05dd4975af7ca2b362dfc84) : Testing\notumor\Te-no_0039.jpg
# Removing duplicate (hash : 665bf16ea1489fb798ee0dd3acaade79) : Training\notumor\Tr-no_0137.jpg
# Removing duplicate (hash : 60e765179ae22c1d69cb6c1233f17354) : Training\notumor\Tr-no_0370.jpg
# Removing duplicate (hash : fc6ff0af19a89f3e2c2c4b1d7f5b9dc6) : Training\notumor\Tr-no_0257.jpg
# Removing duplicate (hash : fc6ff0af19a89f3e2c2c4b1d7f5b9dc6) : Training\notumor\Tr-no_1096.jpg
# Removing duplicate (hash : fc6ff0af19a89f3e2c2c4b1d7f5b9dc6) : Testing\notumor\Te-no_0040.jpg
# Removing duplicate (hash : fc6ff0af19a89f3e2c2c4b1d7f5b9dc6) : Testing\notumor\Te-no_0052.jpg
# Removing duplicate (hash : 632120a6491595c8f2646222e132159e) : Training\notumor\Tr-no_1100.jpg
# Removing duplicate (hash : e450fb2bea94fad366ddebacbe26a4bb) : Training\notumor\Tr-no_0223.jpg
# Removing duplicate (hash : e450fb2bea94fad366ddebacbe26a4bb) : Training\notumor\Tr-no_1101.jpg
# Removing duplicate (hash : b6ce0a54d799d61f77617809c5e78ef2) : Training\notumor\Tr-no_0143.jpg
# Removing duplicate (hash : b6ce0a54d799d61f77617809c5e78ef2) : Training\notumor\Tr-no_0149.jpg
# Removing duplicate (hash : fe2231f523d6d1cabd4670f11b829773) : Training\notumor\Tr-no_0294.jpg
# Removing duplicate (hash : 19e1c11270a5105459a8f52090262d4a) : Training\notumor\Tr-no_0182.jpg
# Removing duplicate (hash : 19e1c11270a5105459a8f52090262d4a) : Training\notumor\Tr-no_1102.jpg
# Removing duplicate (hash : be5ba993f511e6965ff3ced4fec3cc1c) : Testing\notumor\Te-no_0041.jpg
# Removing duplicate (hash : 79ee916b7b7037c4e54832658aa2848a) : Training\notumor\Tr-no_0222.jpg
# Removing duplicate (hash : 79ee916b7b7037c4e54832658aa2848a) : Training\notumor\Tr-no_0282.jpg
# Removing duplicate (hash : 79ee916b7b7037c4e54832658aa2848a) : Training\notumor\Tr-no_0344.jpg
# Removing duplicate (hash : 79ee916b7b7037c4e54832658aa2848a) : Training\notumor\Tr-no_1104.jpg
# Removing duplicate (hash : 79ee916b7b7037c4e54832658aa2848a) : Testing\notumor\Te-no_0080.jpg
# Removing duplicate (hash : 7108f7b2a94c8401f13dae47f666b4e1) : Training\notumor\Tr-no_0164.jpg
# Removing duplicate (hash : 7108f7b2a94c8401f13dae47f666b4e1) : Training\notumor\Tr-no_0242.jpg
# Removing duplicate (hash : 7108f7b2a94c8401f13dae47f666b4e1) : Training\notumor\Tr-no_1117.jpg
# Removing duplicate (hash : bdad00de17000453a6986b7064548f21) : Training\notumor\Tr-no_1106.jpg
# Removing duplicate (hash : 9fd7bb93bb0e52f47db21ccdc091a9fc) : Training\notumor\Tr-no_1107.jpg
# Removing duplicate (hash : 72622502c4407a4cbdc8141151f0e585) : Training\notumor\Tr-no_1108.jpg
# Removing duplicate (hash : 4a22015417b3ab93cd89679e4fa22129) : Training\notumor\Tr-no_0237.jpg
# Removing duplicate (hash : 840b8071cc3279b6332301470adccc98) : Training\notumor\Tr-no_1110.jpg
# Removing duplicate (hash : 840b8071cc3279b6332301470adccc98) : Testing\notumor\Te-no_0042.jpg
# Removing duplicate (hash : 43a7b114cc14ecb127e3feb427e8a2dc) : Training\notumor\Tr-no_1113.jpg
# Removing duplicate (hash : ebd0a54a7b151a9578e4c27c595caffa) : Training\notumor\Tr-no_1115.jpg
# Removing duplicate (hash : e83c5b3fc278777d5a563a2c45f855b1) : Training\notumor\Tr-no_1116.jpg
# Removing duplicate (hash : b71e64834740e5c0589d52e7145a83f0) : Training\notumor\Tr-no_1118.jpg
# Removing duplicate (hash : d4213cadb7fdc260baf35de0ef3072bd) : Training\notumor\Tr-no_1119.jpg
# Removing duplicate (hash : 0d2b9aa3b0a846d39841b6df8f72be72) : Training\notumor\Tr-no_1122.jpg
# Removing duplicate (hash : 0d2b9aa3b0a846d39841b6df8f72be72) : Testing\notumor\Te-no_0043.jpg
# Removing duplicate (hash : 1f6dfa12ce7c3c884d7e2a5a9b802e65) : Training\notumor\Tr-no_1123.jpg
# Removing duplicate (hash : 40881ffd0417f7d60164cbec5265be37) : Training\notumor\Tr-no_1125.jpg
# Removing duplicate (hash : 92d345cb0e551329cb0ab0041b1d531f) : Training\notumor\Tr-no_1129.jpg
# Removing duplicate (hash : 61d0aeacb5768eca8d91ed7915c5648b) : Training\notumor\Tr-no_0189.jpg
# Removing duplicate (hash : 55bc232802b2c8122e875919c6ccbcfa) : Training\notumor\Tr-no_1138.jpg
# Removing duplicate (hash : bd12225700693c193b4f6a120e3eb4b1) : Training\notumor\Tr-no_1141.jpg
# Removing duplicate (hash : bd12225700693c193b4f6a120e3eb4b1) : Testing\notumor\Te-no_0023.jpg
# Removing duplicate (hash : 5562eae4e5ebc10b36e46caeb073fbc5) : Training\notumor\Tr-no_0291.jpg
# Removing duplicate (hash : 5562eae4e5ebc10b36e46caeb073fbc5) : Training\notumor\Tr-no_0324.jpg
# Removing duplicate (hash : 5562eae4e5ebc10b36e46caeb073fbc5) : Training\notumor\Tr-no_0984.jpg
# Removing duplicate (hash : 5562eae4e5ebc10b36e46caeb073fbc5) : Testing\notumor\Te-no_0012.jpg
# Removing duplicate (hash : 5562eae4e5ebc10b36e46caeb073fbc5) : Testing\notumor\Te-no_0044.jpg
# Removing duplicate (hash : 5562eae4e5ebc10b36e46caeb073fbc5) : Testing\notumor\Te-no_0055.jpg
# Removing duplicate (hash : 5562eae4e5ebc10b36e46caeb073fbc5) : Testing\notumor\Te-no_0061.jpg
# Removing duplicate (hash : f6a666f3aad6223c98e59c677b06310c) : Training\notumor\Tr-no_1177.jpg
# Removing duplicate (hash : 9eb9f2c929d940f7333441cf7301f205) : Training\notumor\Tr-no_0187.jpg
# Removing duplicate (hash : 9eb9f2c929d940f7333441cf7301f205) : Training\notumor\Tr-no_1179.jpg
# Removing duplicate (hash : eaed62da90b11d4efc075a06ac31932d) : Training\notumor\Tr-no_0962.jpg
# Removing duplicate (hash : c767afc139c419a9bb2d0fe292730951) : Training\notumor\Tr-no_0235.jpg
# Removing duplicate (hash : c767afc139c419a9bb2d0fe292730951) : Training\notumor\Tr-no_0279.jpg
# Removing duplicate (hash : c767afc139c419a9bb2d0fe292730951) : Testing\notumor\Te-no_0045.jpg
# Removing duplicate (hash : c767afc139c419a9bb2d0fe292730951) : Testing\notumor\Te-no_0050.jpg
# Removing duplicate (hash : c767afc139c419a9bb2d0fe292730951) : Testing\notumor\Te-no_0054.jpg
# Removing duplicate (hash : 1e98f507c83df39e1aefd1e4c2724d7d) : Training\notumor\Tr-no_0980.jpg
# Removing duplicate (hash : 46bdd15e88da99beefcb999aea360457) : Training\notumor\Tr-no_0219.jpg
# Removing duplicate (hash : d5f0f355c306acc7712226cd99f60ef6) : Training\notumor\Tr-no_0200.jpg
# Removing duplicate (hash : 78c6f2102e0ba73c47a344d2880b4071) : Training\notumor\Tr-no_0229.jpg
# Removing duplicate (hash : 78c6f2102e0ba73c47a344d2880b4071) : Training\notumor\Tr-no_1130.jpg
# Removing duplicate (hash : 0cc82102690c7ecbba7b211e9dca4da6) : Training\notumor\Tr-no_0276.jpg
# Removing duplicate (hash : 0cc82102690c7ecbba7b211e9dca4da6) : Training\notumor\Tr-no_1151.jpg
# Removing duplicate (hash : 4295eee904f5e6c205b01cbae01efab6) : Training\notumor\Tr-no_1008.jpg
# Removing duplicate (hash : 2b6b3b3e38f7708c531f92f22b10c2da) : Training\notumor\Tr-no_1178.jpg
# Removing duplicate (hash : 2b6b3b3e38f7708c531f92f22b10c2da) : Testing\notumor\Te-no_0046.jpg
# Removing duplicate (hash : c07e4455eaba1aa3be49247aa6129b90) : Training\notumor\Tr-no_1027.jpg
# Removing duplicate (hash : 5cba73d939059697c0183cf830f339bd) : Training\notumor\Tr-no_0341.jpg
# Removing duplicate (hash : 5cba73d939059697c0183cf830f339bd) : Training\notumor\Tr-no_1181.jpg
# Removing duplicate (hash : 5cba73d939059697c0183cf830f339bd) : Testing\notumor\Te-no_0047.jpg
# Removing duplicate (hash : 5cba73d939059697c0183cf830f339bd) : Testing\notumor\Te-no_0077.jpg
# Removing duplicate (hash : 75b704201c2125c4ac02a0acf836802d) : Training\notumor\Tr-no_1050.jpg
# Removing duplicate (hash : 30833b6b027eb1ca54cdd37ae88213e6) : Training\notumor\Tr-no_1060.jpg
# Removing duplicate (hash : 7ce25d17c7839af995b51e5e308cbd08) : Training\notumor\Tr-no_1071.jpg
# Removing duplicate (hash : 4203b88f2ff81d366a5a4a77674314f6) : Training\notumor\Tr-no_1083.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Training\notumor\Tr-no_0268.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Training\notumor\Tr-no_0332.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Training\notumor\Tr-no_0350.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Training\notumor\Tr-no_0982.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Testing\notumor\Te-no_0011.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Testing\notumor\Te-no_0048.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Testing\notumor\Te-no_0053.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Testing\notumor\Te-no_0068.jpg
# Removing duplicate (hash : e0b9f49e9c57547db3d4490d1d96642a) : Testing\notumor\Te-no_0087.jpg
# Removing duplicate (hash : 2979f0422f022037f032b69fda8cbcba) : Training\notumor\Tr-no_1126.jpg
# Removing duplicate (hash : d52e77fd0e12cfd96d437f00bce28eef) : Training\notumor\Tr-no_1127.jpg
# Removing duplicate (hash : aefc8e18544fc436f74fb90128910a57) : Training\notumor\Tr-no_1128.jpg
# Removing duplicate (hash : d9c32d64bae1e0350522351c6a7cea0b) : Training\notumor\Tr-no_0298.jpg
# Removing duplicate (hash : d9c32d64bae1e0350522351c6a7cea0b) : Training\notumor\Tr-no_1131.jpg
# Removing duplicate (hash : 46e6159f43133d0a4739a0f84fa10411) : Training\notumor\Tr-no_0239.jpg
# Removing duplicate (hash : 46e6159f43133d0a4739a0f84fa10411) : Training\notumor\Tr-no_1135.jpg
# Removing duplicate (hash : 1b2d322078b0e4fe2357333142491edd) : Training\notumor\Tr-no_1133.jpg
# Removing duplicate (hash : e89ab6994c617c31786bfff5c406d0ab) : Training\notumor\Tr-no_0267.jpg
# Removing duplicate (hash : e89ab6994c617c31786bfff5c406d0ab) : Training\notumor\Tr-no_1146.jpg
# Removing duplicate (hash : 71d0f7ccc4fdf4cffccebc64b18c3c9d) : Training\notumor\Tr-no_1137.jpg
# Removing duplicate (hash : 84482e0ddc1ea348e987987c7d9252dd) : Training\notumor\Tr-no_1139.jpg
# Removing duplicate (hash : f026747e5401d8a361e0566ad9166b5d) : Training\notumor\Tr-no_1140.jpg
# Removing duplicate (hash : 68ebae69c42bbb3a6f525a0d966c66fe) : Training\notumor\Tr-no_1182.jpg
# Removing duplicate (hash : 68ebae69c42bbb3a6f525a0d966c66fe) : Testing\notumor\Te-no_0051.jpg
# Removing duplicate (hash : d0ba529e618ee5e2e8bf0f44a9a103c3) : Training\notumor\Tr-no_1142.jpg
# Removing duplicate (hash : 2e793e328d071f0be0cd3a7445d15dc6) : Training\notumor\Tr-no_1144.jpg
# Removing duplicate (hash : 0f4f52fdf26e4689daa7eff79a2e17ba) : Testing\notumor\Te-no_0101.jpg
# Removing duplicate (hash : c87dbb8684ebdb40acbc8b63f000a7c8) : Testing\notumor\Te-no_0102.jpg
# Removing duplicate (hash : 63a03f84b2d451d56d3ea36c97662478) : Testing\notumor\Te-noTr_0002.jpg
# Removing duplicate (hash : f1277f9ee45d44187523901cc1008eed) : Testing\notumor\Te-noTr_0004.jpg
# Removing duplicate (hash : 33c56e184f1729167e9d39abc1a4776d) : Testing\notumor\Te-noTr_0005.jpg
# Removing duplicate (hash : 35be81f4e30b52843e0ec3b93aaf79a7) : Testing\notumor\Te-noTr_0006.jpg
# Removing duplicate (hash : 342b29d63e0103afbe3fab52b8536af2) : Training\notumor\Tr-no_0270.jpg
# Removing duplicate (hash : 342b29d63e0103afbe3fab52b8536af2) : Training\notumor\Tr-no_1149.jpg
# Removing duplicate (hash : 86c4da692caccbe369acf7c886626083) : Training\notumor\Tr-no_1150.jpg
# Removing duplicate (hash : 382a309c1662909431e041df2e825b7e) : Training\notumor\Tr-no_1152.jpg
# Removing duplicate (hash : b57daf6bdf4eba86d249368f83891067) : Training\notumor\Tr-no_1155.jpg
# Removing duplicate (hash : 7c17b4d2dae9f464590fd5ede35aa935) : Training\notumor\Tr-no_1156.jpg
# Removing duplicate (hash : 564d3b81b447a6a62883e7a8bc5476cf) : Training\notumor\Tr-no_1158.jpg
# Removing duplicate (hash : 570dac1fc1d035ab025b3132a5b653ae) : Training\notumor\Tr-no_1161.jpg
# Removing duplicate (hash : ab557cb36fe189781cb124e8119945b1) : Testing\notumor\Te-no_0024.jpg
# Removing duplicate (hash : 6adda2f647be1a756acbd7495482b1d8) : Testing\notumor\Te-no_0056.jpg
# Removing duplicate (hash : 0abe34033d22367d0fe55445050a6f7e) : Training\notumor\Tr-no_1163.jpg
# Removing duplicate (hash : 8039b6fdb903c359232053b858fca09f) : Training\notumor\Tr-no_1164.jpg
# Removing duplicate (hash : a9f96ef19692b1c78cfad347002fe5f3) : Training\notumor\Tr-no_1166.jpg
# Removing duplicate (hash : a9f96ef19692b1c78cfad347002fe5f3) : Testing\notumor\Te-no_0057.jpg
# Removing duplicate (hash : e5437347d710af8e850b85b3680e7f9b) : Training\notumor\Tr-no_1168.jpg
# Removing duplicate (hash : 05fe39a899414d2dab6cad25c301b32c) : Training\notumor\Tr-no_1169.jpg
# Removing duplicate (hash : c6aa58f0d3713e5aec0cf8b373ba02e5) : Training\notumor\Tr-no_1170.jpg
# Removing duplicate (hash : 13fd32f4b20c92e1f12c974210ec3248) : Training\notumor\Tr-no_1171.jpg
# Removing duplicate (hash : 13fd32f4b20c92e1f12c974210ec3248) : Testing\notumor\Te-no_0103.jpg
# Removing duplicate (hash : 6119e8d3172ad5a550a6401e146ff5d5) : Testing\notumor\Te-noTr_0003.jpg
# Removing duplicate (hash : ce33675bd11e9b703d6633037e834531) : Testing\notumor\Te-no_0058.jpg
# Removing duplicate (hash : 8119d65eeb853979f88ace9e90e2b65e) : Training\notumor\Tr-no_0966.jpg
# Removing duplicate (hash : 8119d65eeb853979f88ace9e90e2b65e) : Testing\notumor\Te-no_0059.jpg
# Removing duplicate (hash : 389129c317bcb056247e61ed58b5a3de) : Training\notumor\Tr-no_0336.jpg
# Removing duplicate (hash : 389129c317bcb056247e61ed58b5a3de) : Training\notumor\Tr-no_1183.jpg
# Removing duplicate (hash : 389129c317bcb056247e61ed58b5a3de) : Testing\notumor\Te-no_0019.jpg
# Removing duplicate (hash : 389129c317bcb056247e61ed58b5a3de) : Testing\notumor\Te-no_0062.jpg
# Removing duplicate (hash : 389129c317bcb056247e61ed58b5a3de) : Testing\notumor\Te-no_0073.jpg
# Removing duplicate (hash : 7d5bb24e96e3e482fc7372101793190c) : Training\notumor\Tr-no_1174.jpg
# Removing duplicate (hash : 7d5bb24e96e3e482fc7372101793190c) : Testing\notumor\Te-no_0063.jpg
# Removing duplicate (hash : 87adf2a726fbcefd279bed03d11544ff) : Training\notumor\Tr-no_0970.jpg
# Removing duplicate (hash : 87adf2a726fbcefd279bed03d11544ff) : Testing\notumor\Te-no_0064.jpg
# Removing duplicate (hash : aa995991294e90b0a448dae20d5cf70f) : Training\notumor\Tr-no_0362.jpg
# Removing duplicate (hash : aa995991294e90b0a448dae20d5cf70f) : Training\notumor\Tr-no_0977.jpg
# Removing duplicate (hash : aa995991294e90b0a448dae20d5cf70f) : Testing\notumor\Te-no_0030.jpg
# Removing duplicate (hash : aa995991294e90b0a448dae20d5cf70f) : Testing\notumor\Te-no_0065.jpg
# Removing duplicate (hash : cedd18ecd91954fb35b741a30a606b49) : Testing\notumor\Te-no_0025.jpg
# Removing duplicate (hash : e7e6c4c4d3f3a59be6cac0eca3a8301c) : Training\notumor\Tr-no_0971.jpg
# Removing duplicate (hash : e7e6c4c4d3f3a59be6cac0eca3a8301c) : Testing\notumor\Te-no_0066.jpg
# Removing duplicate (hash : b3985de17782311036e2c40e43eba428) : Training\notumor\Tr-no_0347.jpg
# Removing duplicate (hash : b3985de17782311036e2c40e43eba428) : Training\notumor\Tr-no_0373.jpg
# Removing duplicate (hash : b3985de17782311036e2c40e43eba428) : Training\notumor\Tr-no_1088.jpg
# Removing duplicate (hash : b3985de17782311036e2c40e43eba428) : Testing\notumor\Te-noTr_0001.jpg
# Removing duplicate (hash : b3985de17782311036e2c40e43eba428) : Testing\notumor\Te-no_0031.jpg
# Removing duplicate (hash : b3985de17782311036e2c40e43eba428) : Testing\notumor\Te-no_0067.jpg
# Removing duplicate (hash : b3985de17782311036e2c40e43eba428) : Testing\notumor\Te-no_0084.jpg
# Removing duplicate (hash : 77d84ba95eacd41f5f1f214b38f29b7b) : Testing\notumor\Te-no_0029.jpg
# Removing duplicate (hash : 77d84ba95eacd41f5f1f214b38f29b7b) : Testing\notumor\Te-no_0069.jpg
# Removing duplicate (hash : 5a2b03cf1973b4e0c5e18a7b439b900e) : Training\notumor\Tr-no_0974.jpg
# Removing duplicate (hash : 5a2b03cf1973b4e0c5e18a7b439b900e) : Testing\notumor\Te-no_0018.jpg
# Removing duplicate (hash : 5a2b03cf1973b4e0c5e18a7b439b900e) : Testing\notumor\Te-no_0070.jpg
# Removing duplicate (hash : 4ceee6f7d03d8681912af6196397b40f) : Training\notumor\Tr-no_0394.jpg
# Removing duplicate (hash : 4ceee6f7d03d8681912af6196397b40f) : Training\notumor\Tr-no_0978.jpg
# Removing duplicate (hash : 4ceee6f7d03d8681912af6196397b40f) : Testing\notumor\Te-no_0021.jpg
# Removing duplicate (hash : 4ceee6f7d03d8681912af6196397b40f) : Testing\notumor\Te-no_0072.jpg
# Removing duplicate (hash : 78a16b2244a7587f8c1a587fae16947c) : Testing\notumor\Te-no_0074.jpg
# Removing duplicate (hash : 1387112a2ca5824007c964f73761ca75) : Training\notumor\Tr-no_0981.jpg
# Removing duplicate (hash : 1387112a2ca5824007c964f73761ca75) : Testing\notumor\Te-no_0076.jpg
# Removing duplicate (hash : 8fe49fdfd19a97616394d4ece3d0184b) : Training\notumor\Tr-no_1153.jpg
# Removing duplicate (hash : 8fe49fdfd19a97616394d4ece3d0184b) : Testing\notumor\Te-no_0026.jpg
# Removing duplicate (hash : cc712e0106aa07953906b25f2e7a5598) : Testing\notumor\Te-no_0078.jpg
# Removing duplicate (hash : c03743fd455214695410b07a45445df6) : Testing\notumor\Te-no_0079.jpg
# Removing duplicate (hash : 46187030cd69d096f561e16f2b53752e) : Training\notumor\Tr-no_1103.jpg
# Removing duplicate (hash : 46187030cd69d096f561e16f2b53752e) : Testing\notumor\Te-no_0083.jpg
# Removing duplicate (hash : 46187030cd69d096f561e16f2b53752e) : Testing\notumor\Te-no_0093.jpg
# Removing duplicate (hash : c921d7f6620c88b5c5414b33a6e39f28) : Testing\notumor\Te-no_0085.jpg
# Removing duplicate (hash : 855c4050a3a928dd2f2ee9f800cb8873) : Training\notumor\Tr-no_0964.jpg
# Removing duplicate (hash : 855c4050a3a928dd2f2ee9f800cb8873) : Testing\notumor\Te-no_0086.jpg
# Removing duplicate (hash : df7e8a0bf66346074cdfd208dca5b0fd) : Testing\notumor\Te-no_0028.jpg
# Removing duplicate (hash : eabe8f8848daf6e6c0a0ae6f5b60129c) : Training\notumor\Tr-no_1089.jpg
# Removing duplicate (hash : eabe8f8848daf6e6c0a0ae6f5b60129c) : Testing\notumor\Te-noTr_0007.jpg
# Removing duplicate (hash : eabe8f8848daf6e6c0a0ae6f5b60129c) : Testing\notumor\Te-no_0088.jpg
# Removing duplicate (hash : e97938b59008eb5d836975b7948ed67b) : Training\notumor\Tr-no_0969.jpg
# Removing duplicate (hash : e97938b59008eb5d836975b7948ed67b) : Testing\notumor\Te-no_0089.jpg
# Removing duplicate (hash : 9c856845544d5264bebfadbad48eb175) : Testing\notumor\Te-no_0090.jpg
# Removing duplicate (hash : 1f8e24f187a6ccdeb6cf9ff4122f1227) : Testing\notumor\Te-no_0091.jpg
# Removing duplicate (hash : 16ae0ed310da7fb1c9bfdb648544815e) : Testing\notumor\Te-no_0092.jpg
# Removing duplicate (hash : 7269784311c0416571c63e4f7b433e2a) : Testing\notumor\Te-no_0094.jpg
# Removing duplicate (hash : f464a61c4db5e123cfa470cd5ab789c0) : Testing\notumor\Te-no_0095.jpg
# Removing duplicate (hash : 7b87a432aa0fd085c8175861d59926c3) : Testing\notumor\Te-no_0096.jpg
# Removing duplicate (hash : dfaa0b739de61f939192be4eea7fd516) : Testing\notumor\Te-no_0097.jpg
# Removing duplicate (hash : 6540b075d2203949621fb7e5319e51d3) : Testing\notumor\Te-no_0098.jpg
# Removing duplicate (hash : 26c0900bf911e5ed884762f141ab3fcc) : Testing\notumor\Te-no_0099.jpg
# Removing duplicate (hash : 4bb4e278677833186fa60a9e12178ef1) : Training\notumor\Tr-no_0979.jpg
# Removing duplicate (hash : 4bb4e278677833186fa60a9e12178ef1) : Testing\notumor\Te-no_0100.jpg
# Removing duplicate (hash : eef725fec0cda3c3cbfff364722dd54f) : Training\notumor\Tr-no_0989.jpg
# Removing duplicate (hash : eef725fec0cda3c3cbfff364722dd54f) : Testing\notumor\Te-no_0032.jpg
# Removing duplicate (hash : a83cb7f08470fe605a874d75e12aec8a) : Training\notumor\Tr-no_1157.jpg
# Removing duplicate (hash : 2e3de2e90728f34969828955a1b242b2) : Testing\notumor\Te-no_0060.jpg
# Removing duplicate (hash : b43ac57b78e6c93f8ad6549827de5739) : Testing\notumor\Te-no_0010.jpg
# Removing duplicate (hash : 47de6b02c55fb97b1d294a9193cbf5cc) : Testing\notumor\Te-noTr_0008.jpg
# Removing duplicate (hash : 87faa38085c7eba430487ff7d9599694) : Testing\notumor\Te-noTr_0009.jpg
# Removing duplicate (hash : c00ff93d39654b9bd8772a3a49d91dfd) : Testing\notumor\Te-no_0016.jpg
# Removing duplicate (hash : 87e3305713604aecf1a86891fc8929cd) : Testing\notumor\Te-no_0017.jpg
# Removing duplicate (hash : cd3644e2865af324bca5bd9160f8cc55) : Testing\notumor\Te-no_0027.jpg
# Removing duplicate (hash : bfa696d934f47cee4a0873f972a35c21) : Testing\notumor\Te-no_0014.jpg
# Removing duplicate (hash : 99e0890275f773a6baa17d02fc0bdefb) : Training\pituitary\Tr-pi_0157.jpg
# Removing duplicate (hash : b612aa0d702020c3dd896f4294000a02) : Training\pituitary\Tr-pi_0108.jpg
# Removing duplicate (hash : 7aace426ed99cbee63e3f7fb55465590) : Training\pituitary\Tr-pi_0160.jpg
# Removing duplicate (hash : 9ac2bb858e51e57e9652feba3728004e) : Training\pituitary\Tr-pi_0170.jpg
# Removing duplicate (hash : 690f2c41084c1b8727b1c51812153004) : Training\pituitary\Tr-pi_0227.jpg
# Removing duplicate (hash : 15cf7ebeefbbb7e57abf759acc3af7ef) : Training\pituitary\Tr-pi_0321.jpg
# Removing duplicate (hash : 406052e058bc64ffed1f9c9e2b65687c) : Training\pituitary\Tr-pi_0343.jpg
# Removing duplicate (hash : a28c0aaf1e5ee802731aef2571094300) : Training\pituitary\Tr-pi_0517.jpg
# Removing duplicate (hash : a28c0aaf1e5ee802731aef2571094300) : Training\pituitary\Tr-pi_0518.jpg
# Removing duplicate (hash : a28c0aaf1e5ee802731aef2571094300) : Testing\pituitary\Te-piTr_0001.jpg
# Removing duplicate (hash : 05c3caea567ffd77caf79c12654b87e5) : Training\pituitary\Tr-pi_0527.jpg
# Removing duplicate (hash : 05c3caea567ffd77caf79c12654b87e5) : Training\pituitary\Tr-pi_0529.jpg
# Removing duplicate (hash : 669562a698a0159bde95c5e3bee8077d) : Testing\pituitary\Te-pi_0044.jpg
# Removing duplicate (hash : 684f3a8c6a38c754af74fe7d91396131) : Testing\pituitary\Te-pi_0045.jpg
# Removing duplicate (hash : 667db113b8954435f1ceab3122f5b296) : Training\pituitary\Tr-pi_0677.jpg
# Removing duplicate (hash : 584ca4664acb9536e369e49eb98239ad) : Testing\pituitary\Te-pi_0055.jpg
# Removing duplicate (hash : 3326fd02a76cf696c9679794f3aaf14b) : Testing\pituitary\Te-pi_0066.jpg
# Removing duplicate (hash : 61388b0e333fe750b3bd0c7912846625) : Testing\glioma\Te-gl_0029.jpg
# Removing duplicate (hash : 698ac9e379771e54f2dd985b1d58f8dd) : Testing\meningioma\Te-me_0031.jpg
# Removing duplicate (hash : 784114ee48882bf1b8b7b92a559da83d) : Testing\meningioma\Te-me_0073.jpg
# Number of duplicates : 297

# %%
def get_class_paths(path):
    """
    path: should be either "Training" or "Testing"
    """
    classes = []
    class_paths = []
    
    for label in os.listdir(path):
        label_path = os.path.join(path, label)

        if os.path.isdir(label_path):
            for image in os.listdir(label_path):
                image_path = os.path.join(label_path, image)

                classes.append(label)
                class_paths.append(image_path)
    
    df = pd.DataFrame({
        'Class Path': class_paths,
        'Class': classes
    })

    return df

# %%
train_df = get_class_paths("Training")
val_counts = pd.DataFrame(train_df['Class'].value_counts())
total_count = len(train_df)
print()
# Out:
# Ratio of class Class to total count: pituitary     0.261728
# notumor       0.257562
# meningioma    0.241442
# glioma        0.239268
# Name: Class, dtype: float64

# %%
test_df = get_class_paths("Testing")
val_counts = pd.DataFrame(test_df['Class'].value_counts())
total_count = len(test_df)
for c in val_counts:
    print(f"Ratio of class {c} to total count: {val_counts[c]/total_count}")
# Out:
# Ratio of class Class to total count: notumor       0.256432
# meningioma    0.250622
# glioma        0.248133
# pituitary     0.244813
# Name: Class, dtype: float64

# %%
# move all data to one folder

for path in ["Training", "Testing"]:
    for label in os.listdir(path):
        label_path = os.path.join(path, label)
        new_label_path = os.path.join("allData", label)
        if not os.path.isdir(new_label_path):
            os.makedirs(new_label_path)
        if os.path.isdir(label_path):
            for image in os.listdir(label_path):
                image_path = os.path.join(label_path, image)
                new_image_path = os.path.join(new_label_path, image)
                os.rename(image_path, new_image_path)

# %%
df = get_class_paths("allData")

# %%
from sklearn.model_selection import train_test_split

# %%
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['Class'])

# %%
train_df['Class'].value_counts()/len(train_df)
# Out:
# pituitary     0.258736
# notumor       0.257249
# meningioma    0.243123
# glioma        0.240892
# Name: Class, dtype: float64

# %%
test_df['Class'].value_counts()/len(test_df)
# Out:
# pituitary     0.258544
# notumor       0.257801
# meningioma    0.242942
# glioma        0.240713
# Name: Class, dtype: float64
